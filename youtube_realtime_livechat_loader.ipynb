# %% [markdown]
# www.youtube.com/watch?v=???のリクエストでcontinuationを取得する。
# 場所：
# ```js
# ytInitialData['contents']['twoColumnWatchNextResults']['conversationBar']['liveChatRenderer']['continuations'][0]['reloadContinuationData']['continuation']
# ```
#
# get_live_chat リクエスト
# Request URL: https://www.youtube.com/youtubei/v1/live_chat/get_live_chat
#
# https://curlconverter.com/
#
# 必須条件：
# リクエストヘッダ
# ペイロード（continuationは更新する）
# cookie
#
# 新しいチャットを取得するにはcontinuationを更新するだけ。
# 一定時間経過するとチャットが取得できなくなる。

# %%
import re, requests, json, time
from time import sleep

# %%
videoId = "7Cwuruo1coQ"

# %%
req = requests.get("https://www.youtube.com/watch?v="+videoId)

res = re.search(r"var ytInitialData = {.*}}}}", req.text)
res = res.group().replace("var ytInitialData = ", "")
ytInitialData = json.loads(res)
continuation_key = ytInitialData['contents']['twoColumnWatchNextResults']['conversationBar']['liveChatRenderer']['continuations'][0]['reloadContinuationData']['continuation']
print(continuation_key)
# Out:
# 0ofMyAN0GlhDaWtxSndvWVZVTmlOazlpUlMxWVIwTmpkRTh6VjNKcVVscERMV04zRWdzM1EzZDFjblZ2TVdOdlVSb1Q2cWpkdVFFTkNnczNRM2QxY25Wdk1XTnZVU0FCMAGCAQIIBIgBAaABk9aQ9_6_9wKoAQCyAQA%3D

# %%
cookies = {
    'VISITOR_INFO1_LIVE': 'U0au2gzNt80',
    '_ga': 'GA1.2.177397464.1631949760',
    'HSID': 'AL8bONywzWDKDiv0u',
    'SSID': 'AkPWjamfBbzgZrEkT',
    'APISID': 'WP_-b_3idG_D9lSn/A6qNbLIwzlBPEEBs3',
    'SAPISID': 'OS1ekYIXfDITXTFC/Aj1DLV3aCPjHkEFKR',
    '__Secure-1PAPISID': 'OS1ekYIXfDITXTFC/Aj1DLV3aCPjHkEFKR',
    '__Secure-3PAPISID': 'OS1ekYIXfDITXTFC/Aj1DLV3aCPjHkEFKR',
    'LOGIN_INFO': 'AFmmF2swRQIhAJMUVaNNYxkit5oSWAyBiYQMKCu-bI8ws-0YVpcX1M9nAiAk-bT9DXYMOBWDJAcV2FUSc7sflLwsauxR8bgqI7jV1Q:QUQ3MjNmeEhSQVowRi1zVXNKWTVWVHplY25CcnNPWWFCN1EtbURockpldnVYWXlQaENrbWQ4Q2FnSERiWHQ4VmpMalJ4NmktaHJwZEFjd1VLYVNPd2lFNmNEY2JHRktLVVhXQ0dKMnc2U2xldGRXbXA5bDZCWjlrRVpyZGZNcFF4SHJGVnRtRWRWcWZKTXRGLVJ5WVZfWW5MVXAxenpjbnJB',
    'PREF': 'tz=Asia.Tokyo&f6=40000400&f5=30000&volume=45',
    'SID': 'JgjCcJc2jkcm776NbVA3D7xtlOX6ddbFQSeAbFv7AsQfwYGS8ggzqHBojUZ0F6wirt6KHw.',
    '__Secure-1PSID': 'JgjCcJc2jkcm776NbVA3D7xtlOX6ddbFQSeAbFv7AsQfwYGSO3oBMS6Ho4jWO-JSI_SpdQ.',
    '__Secure-3PSID': 'JgjCcJc2jkcm776NbVA3D7xtlOX6ddbFQSeAbFv7AsQfwYGS5WvpM0DbjnNcku2wMzJsRQ.',
    'YSC': 'A0TGC7Hp514',
    'SIDCC': 'AJi4QfGdXUyuV_lbmc9M6eT9qXXM6_K6TKOnUldwOU728lhjeENG84ES6XNa72LKkwId_35gJCZT',
    '__Secure-3PSIDCC': 'AJi4QfFQSRQlMRs_aTMOBgFqctrpNMt4j_6qmb3bKi5eBP-uNZ2bgH6awa6mX-_Olobe_6pyupo',
}

headers = {
    'authority': 'www.youtube.com',
    'accept': '*/*',
    'accept-language': 'ja-JP,ja;q=0.9,en-US;q=0.8,en;q=0.7',
    'dnt': '1',
    'origin': 'https://www.youtube.com',
    'referer': 'https://www.youtube.com/live_chat?is_popout=1&v='+videoId,
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36',
    'x-goog-authuser': '0',
    'x-goog-visitor-id': 'CgtVMGF1Mmd6TnQ4MCiI2bmTBg%3D%3D',
    'x-origin': 'https://www.youtube.com',
    'x-youtube-bootstrap-logged-in': 'true',
    'x-youtube-client-name': '1',
    'x-youtube-client-version': '2.20220429.00.00',
}

params = {
    'key': 'AIzaSyAO_FJ2SlqU8Q4STEHLGCilw_Y9_11qcW8',
    'prettyPrint': 'false',
}

json_data = {
    'context': {
        'client': {
            'hl': 'ja',
            'gl': 'JP',
            'remoteHost': '221.242.137.177',
            'deviceMake': '',
            'deviceModel': '',
            'visitorData': 'CgtVMGF1Mmd6TnQ4MCiI2bmTBg%3D%3D',
            'userAgent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36,gzip(gfe)',
            'clientName': 'WEB',
            'clientVersion': '2.20220429.00.00',
            'osName': 'Windows',
            'osVersion': '10.0',
            'originalUrl': 'https://www.youtube.com/live_chat?is_popout=1&v='+videoId,
            'platform': 'DESKTOP',
            'clientFormFactor': 'UNKNOWN_FORM_FACTOR',
            'configInfo': {
                'appInstallData': 'CIjZuZMGEPyLrgUQ8IKuBRDokK4FEJOPrgUQgo6uBRCY3v0SEJjqrQUQuIuuBRDUg64FELfLrQUQ6pCuBRCq2q0FENfh_RIQ2L6tBRCR-PwS',
            },
            'userInterfaceTheme': 'USER_INTERFACE_THEME_DARK',
            'timeZone': 'Asia/Tokyo',
            'browserName': 'Chrome',
            'browserVersion': '100.0.4896.127',
            'screenWidthPoints': 600,
            'screenHeightPoints': 599,
            'screenPixelDensity': 1,
            'screenDensityFloat': 1,
            'utcOffsetMinutes': 540,
            'connectionType': 'CONN_CELLULAR_4G',
            'memoryTotalKbytes': '8000000',
            'mainAppWebInfo': {
                'graftUrl': 'https://www.youtube.com/live_chat?is_popout=1&v='+videoId,
                'webDisplayMode': 'WEB_DISPLAY_MODE_BROWSER',
                'isWebNativeShareAvailable': True,
            },
        },
        'user': {
            'lockedSafetyMode': False,
        },
        'request': {
            'useSsl': True,
            'internalExperimentFlags': [],
            'consistencyTokenJars': [],
        },
        'clickTracking': {'clickTrackingParams': 'CAEQl98BIhMIzrnCga2-9wIVzUcqCh1x6AGT',},
        'adSignalsInfo': {
            'params': [
                {"key":"dt","value":"1651421056459"},
                {"key":"flash","value":"0"},
                {"key":"frm","value":"1"},
                {"key":"u_tz","value":"540"},
                {"key":"u_his","value":"10"},
                {"key":"u_h","value":"1080"},
                {"key":"u_w","value":"1920"},
                {"key":"u_ah","value":"1040"},
                {"key":"u_aw","value":"1920"},
                {"key":"u_cd","value":"24"},
                {"key":"bc","value":"31"},
                {"key":"bih","value":"788"},
                {"key":"biw","value":"1395"},
                {"key":"brdim","value":"1942,75,1942,75,1920,0,1427,908,400,561"},
                {"key":"vis","value":"1"},
                {"key":"wgl","value":"true"},
                {"key":"ca_type","value":"image"},
            ],
        },
    },
    'continuation': continuation_key,
    'webClientInfo': {
        'isDocumentHidden': True,
    },
}

id_queue = []
id_queue_limit = 100 # チャットIDを格納して重複を防ぐ

while True:
    response = requests.post('https://www.youtube.com/youtubei/v1/live_chat/get_live_chat', params=params, cookies=cookies, headers=headers, json=json_data)
    print("status_code:", response.status_code)

    live_chat = json.loads(response.text)
    chatItems = live_chat['continuationContents']['liveChatContinuation']['actions']
    continuation_key = live_chat['continuationContents']['liveChatContinuation']['continuations'][0]['timedContinuationData']['continuation']
    timeoutMs = int(live_chat['continuationContents']['liveChatContinuation']['continuations'][0]['timedContinuationData']['timeoutMs']) / 1000
    for chatItem in chatItems:
        try:
            text = chatItem['addChatItemAction']['item']['liveChatTextMessageRenderer']['message']['runs'][0]['text']
            timeStamp = int(chatItem['addChatItemAction']['item']['liveChatTextMessageRenderer']['timestampUsec']) / 1000000
            id = chatItem['addChatItemAction']['item']['liveChatTextMessageRenderer']['id']
            if id not in id_queue:
                print(timeStamp, text)
                id_queue.append(id)
        except: pass

    # id_queue 100件に収める処理
    if id_queue_limit < len(id_queue):
        id_queue = id_queue[len(id_queue)-id_queue_limit:len(id_queue)]

    sleep(timeoutMs)

# %%
{
    'clickTrackingParams': 'CAEQl98BIhMI8MCV1dm-9wIVsbdWAR1uWwqm',
    'addChatItemAction': {
        'item': {
            'liveChatTextMessageRenderer': {
                'message': {'runs': [{'text': 'RPR'}]},
                'authorName': {'simpleText': 'Lanny Yang'},
                'authorPhoto': {'thumbnails': [
                    {
                        'url': 'https://yt4.ggpht.com/ytc/AKedOLS5hX6vkfy6flvk_uH57YkU3-g93aIRwHTQMIwInw=s32-c-k-c0x00ffffff-no-rj',
                        'width': 32,
                        'height': 32},
                    {
                        'url': 'https://yt4.ggpht.com/ytc/AKedOLS5hX6vkfy6flvk_uH57YkU3-g93aIRwHTQMIwInw=s64-c-k-c0x00ffffff-no-rj',
                        'width': 64,
                        'height': 64}]},
                    'contextMenuEndpoint': {
                        'clickTrackingParams': 'CAEQl98BIhMI8MCV1dm-9wIVsbdWAR1uWwqm',
                        'commandMetadata': {'webCommandMetadata': {'ignoreNavigation': True}},
                        'liveChatItemContextMenuEndpoint': {'params': ''}},
                    'id': 'CjkKGkNMVHduTW5adnZjQ0ZmYkJ3Z1FkeHJrTHVREhtDUFBKck92WXZ2Y0NGWnhPRHdJZHVTd0c1ZzE%3D',
                    'timestampUsec': '1651421789763671',
                    'authorExternalChannelId': 'UCOLk_oHDlAnOypcpA8Poe_A',
                    'contextMenuAccessibility': {'accessibilityData': {'label': 'チャットの操作'}},
                    'trackingParams': 'CAEQl98BIhMI8MCV1dm-9wIVsbdWAR1uWwqm'}},
                    'clientId': 'CPPJrOvYvvcCFZxODwIduSwG5g1'}},
